# %% [markdown]
# <a href="https://colab.research.google.com/github/RawipatChin/Navigation/blob/main/docs/examples/sam3_image_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SAM3 Image Segmentation for Remote Sensing
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/segment-geospatial/blob/main/docs/examples/sam3_image_segmentation.ipynb)
#
# This notebook demonstrates how to use the Segment Anything Model 3 (SAM3) for segmenting remote sensing images using the `samgeo3` module.
#
# ## Installation
#
# First, make sure you have the required dependencies installed:

# %%
# %pip install "segment-geospatial[samgeo3]"
# Out:
# Collecting segment-geospatial[samgeo3]
#   Downloading segment_geospatial-1.4.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (5.2.2)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (1.1.4)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (1.23.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (2.0.2)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (5.0.0.93)
# Collecting patool (from segment-geospatial[samgeo3])
#   Downloading patool-4.0.5-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (11.3.0)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (3.7.2)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (1.5.0)
# Collecting segment_anything (from segment-geospatial[samgeo3])
#   Downloading segment_anything-1.0-py3-none-any.whl.metadata (487 bytes)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (2.1.2)
# Collecting smoothify (from segment-geospatial[samgeo3])
#   Downloading smoothify-0.3.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (2.11.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (0.26.0+cpu)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (4.67.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (2026.3.0)
# Collecting sam3>=0.1.4 (from segment-geospatial[samgeo3])
#   Downloading sam3-0.1.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (1.6.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (0.25.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (5.13.1)
# Collecting buildingregulariser (from segment-geospatial[samgeo3])
#   Downloading buildingregulariser-0.2.5-py3-none-any.whl.metadata (8.5 kB)
# Collecting leafmap (from segment-geospatial[samgeo3])
#   Downloading leafmap-0.63.1-py2.py3-none-any.whl.metadata (17 kB)
# Collecting localtileserver (from segment-geospatial[samgeo3])
#   Downloading localtileserver-1.0.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (3.8.14)
# Collecting triton>=3.5.1 (from segment-geospatial[samgeo3])
#   Downloading triton-3.7.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from segment-geospatial[samgeo3]) (2025.12.0)
# Requirement already satisfied: timm>=1.0.17 in /usr/local/lib/python3.12/dist-packages (from sam3>=0.1.4->segment-geospatial[samgeo3]) (1.0.28)
# Collecting ftfy<6.4.0,>=6.1.1 (from sam3>=0.1.4->segment-geospatial[samgeo3])
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex>=2025.11.3 in /usr/local/lib/python3.12/dist-packages (from sam3>=0.1.4->segment-geospatial[samgeo3]) (2025.11.3)
# Collecting iopath<0.2.0,>=0.1.10 (from sam3>=0.1.4->segment-geospatial[samgeo3])
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting typing_extensions<4.16.0,>=4.8.0 (from sam3>=0.1.4->segment-geospatial[samgeo3])
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from sam3>=0.1.4->segment-geospatial[samgeo3]) (0.8.2)
# Requirement already satisfied: pycocotools<2.1.0,>=2.0.10 in /usr/local/lib/python3.12/dist-packages (from sam3>=0.1.4->segment-geospatial[samgeo3]) (2.0.11)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo3]) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo3]) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo3]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo3]) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo3]) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo3]) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->segment-geospatial[samgeo3]) (6.0.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->segment-geospatial[samgeo3]) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers->segment-geospatial[samgeo3]) (0.26.8)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from transformers->segment-geospatial[samgeo3]) (0.8.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->segment-geospatial[samgeo3]) (0.13.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->segment-geospatial[samgeo3]) (2.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj->segment-geospatial[samgeo3]) (2026.6.17)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->segment-geospatial[samgeo3]) (4.13.5)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown->segment-geospatial[samgeo3]) (2.32.4)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (0.9.21)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (0.12.47)
# Collecting duckdb>=1.4.1 (from leafmap->segment-geospatial[samgeo3])
#   Downloading duckdb-1.5.5-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (0.20.0)
# Collecting geojson (from leafmap->segment-geospatial[samgeo3])
#   Downloading geojson-3.3.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipyevents>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (2.0.4)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (0.20.0)
# Collecting ipyvue>=1.12.0 (from leafmap->segment-geospatial[samgeo3])
#   Downloading ipyvue-1.12.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting ipyvuetify (from leafmap->segment-geospatial[samgeo3])
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (7.7.1)
# Collecting maplibre (from leafmap->segment-geospatial[samgeo3])
#   Downloading maplibre-0.3.6-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (5.24.1)
# Collecting pystac-client (from leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: python-box in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (7.4.1)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from leafmap->segment-geospatial[samgeo3]) (0.11.2)
# Collecting whiteboxgui (from leafmap->segment-geospatial[samgeo3])
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: fastapi>=0.100.0 in /usr/local/lib/python3.12/dist-packages (from localtileserver->segment-geospatial[samgeo3]) (0.139.0)
# Requirement already satisfied: uvicorn[standard] in /usr/local/lib/python3.12/dist-packages (from localtileserver->segment-geospatial[samgeo3]) (0.51.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from localtileserver->segment-geospatial[samgeo3]) (3.1.6)
# Collecting jupyter-loopback>=0.3.3 (from jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3])
#   Downloading jupyter_loopback-0.3.3-py3-none-any.whl.metadata (7.6 kB)
# Collecting rio-tiler (from localtileserver->segment-geospatial[samgeo3])
#   Downloading rio_tiler-9.4.2-py3-none-any.whl.metadata (11 kB)
# Collecting rio-cogeo (from localtileserver->segment-geospatial[samgeo3])
#   Downloading rio_cogeo-7.0.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting server-thread (from localtileserver->segment-geospatial[samgeo3])
#   Downloading server_thread-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial[samgeo3]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial[samgeo3]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial[samgeo3]) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial[samgeo3]) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial[samgeo3]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial[samgeo3]) (2.9.0.post0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->segment-geospatial[samgeo3]) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->segment-geospatial[samgeo3]) (26.1.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->segment-geospatial[samgeo3]) (0.7.2)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->segment-geospatial[samgeo3]) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->segment-geospatial[samgeo3]) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->segment-geospatial[samgeo3]) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->segment-geospatial[samgeo3]) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->segment-geospatial[samgeo3]) (0.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->segment-geospatial[samgeo3]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->segment-geospatial[samgeo3]) (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (1.3.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (2.13.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy->segment-geospatial[samgeo3]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->segment-geospatial[samgeo3]) (1.14.0)
# Requirement already satisfied: starlette>=0.46.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver->segment-geospatial[samgeo3]) (1.3.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver->segment-geospatial[samgeo3]) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver->segment-geospatial[samgeo3]) (0.0.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy<6.4.0,>=6.1.1->sam3>=0.1.4->segment-geospatial[samgeo3]) (0.8.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->segment-geospatial[samgeo3]) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->segment-geospatial[samgeo3]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->segment-geospatial[samgeo3]) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->segment-geospatial[samgeo3]) (0.16.0)
# Collecting portalocker (from iopath<0.2.0,>=0.1.10->sam3>=0.1.4->segment-geospatial[samgeo3])
#   Downloading portalocker-4.1.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap->segment-geospatial[samgeo3]) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap->segment-geospatial[samgeo3]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap->segment-geospatial[samgeo3]) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap->segment-geospatial[samgeo3]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap->segment-geospatial[samgeo3]) (3.0.16)
# Requirement already satisfied: jupyter-server>=2 in /usr/local/lib/python3.12/dist-packages (from jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (2.20.0)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (6.5.7)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from anywidget->leafmap->segment-geospatial[samgeo3]) (0.15.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->segment-geospatial[samgeo3]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->segment-geospatial[samgeo3]) (2026.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy->segment-geospatial[samgeo3]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy->segment-geospatial[samgeo3]) (2.46.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->segment-geospatial[samgeo3]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->segment-geospatial[samgeo3]) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->segment-geospatial[samgeo3]) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->segment-geospatial[samgeo3]) (1.3.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.12->spacy->segment-geospatial[samgeo3]) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers->segment-geospatial[samgeo3]) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers->segment-geospatial[samgeo3]) (13.9.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy->segment-geospatial[samgeo3]) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy->segment-geospatial[samgeo3]) (8.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->segment-geospatial[samgeo3]) (2.8.4)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.12/dist-packages (from bqplot->leafmap->segment-geospatial[samgeo3]) (0.2.3)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium->leafmap->segment-geospatial[samgeo3]) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->localtileserver->segment-geospatial[samgeo3]) (3.0.3)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet->leafmap->segment-geospatial[samgeo3]) (0.20.0)
# Collecting eval-type-backport (from maplibre->leafmap->segment-geospatial[samgeo3])
#   Downloading eval_type_backport-0.4.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->leafmap->segment-geospatial[samgeo3]) (9.1.4)
# Collecting pystac>=1.10.0 (from pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac-1.15.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->segment-geospatial[samgeo3]) (1.7.1)
# Collecting morecantile<8.0,>=5.0 (from rio-cogeo->localtileserver->segment-geospatial[samgeo3])
#   Downloading morecantile-7.0.3-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->segment-geospatial[samgeo3]) (6.2.6)
# Collecting color-operations (from rio-tiler->localtileserver->segment-geospatial[samgeo3])
#   Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: httpx2 in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->segment-geospatial[samgeo3]) (2.5.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->segment-geospatial[samgeo3]) (2.14.1)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.12/dist-packages (from server-thread->localtileserver->segment-geospatial[samgeo3]) (3.1.8)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->segment-geospatial[samgeo3]) (0.8.0)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->segment-geospatial[samgeo3]) (1.2.2)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->segment-geospatial[samgeo3]) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->segment-geospatial[samgeo3]) (1.2.0)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->segment-geospatial[samgeo3]) (15.0.1)
# Collecting ipytree (from whiteboxgui->leafmap->segment-geospatial[samgeo3])
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl.metadata (849 bytes)
# Collecting whitebox (from whiteboxgui->leafmap->segment-geospatial[samgeo3])
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.2.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (26.2.1)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3])
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (25.1.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (7.17.1)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (1.9.0)
# Collecting pystac-core<2,>=1.15.0 (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_core-1.15.2-py3-none-any.whl.metadata (1.3 kB)
# Collecting pystac-ext-classification (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_classification-2.0.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting pystac-ext-datacube (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_datacube-2.2.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-eo (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_eo-1.1.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-file (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_file-2.1.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-grid (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_grid-1.1.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-item-assets (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_item_assets-1.0.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-label (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_label-1.0.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-mgrs (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_mgrs-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-mlm (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_mlm-1.4.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting pystac-ext-pointcloud (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_pointcloud-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-projection (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_projection-2.0.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting pystac-ext-raster (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_raster-1.1.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-render (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_render-2.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-sar (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_sar-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-sat (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_sat-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-scientific (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_scientific-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-storage (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_storage-2.0.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-table (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_table-1.2.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-timestamps (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_timestamps-1.1.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-version (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_version-1.2.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-view (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_view-1.0.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-xarray-assets (from pystac>=1.10.0->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3])
#   Downloading pystac_ext_xarray_assets-1.0.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jsonschema~=4.18 in /usr/local/lib/python3.12/dist-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3]) (4.26.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers->segment-geospatial[samgeo3]) (4.2.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy->segment-geospatial[samgeo3]) (2.2.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (6.5.7)
# Requirement already satisfied: httpcore2==2.5.0 in /usr/local/lib/python3.12/dist-packages (from httpx2->rio-tiler->localtileserver->segment-geospatial[samgeo3]) (2.5.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.12/dist-packages (from httpx2->rio-tiler->localtileserver->segment-geospatial[samgeo3]) (0.10.4)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (25.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.8.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial[samgeo3]) (2026.6.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (4.10.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (0.1.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers->segment-geospatial[samgeo3]) (0.1.2)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (3.3.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (2.21.2)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.7.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (1.5.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (25.10.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap->segment-geospatial[samgeo3]) (0.2.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (2.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (3.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=2->jupyter-loopback>=0.3.3->jupyter-loopback[comm]>=0.3.3->localtileserver->segment-geospatial[samgeo3]) (1.4.0)
# Downloading sam3-0.1.4-py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 12.5 MB/s eta 0:00:00
# Downloading triton-3.7.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (197.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 MB 5.8 MB/s eta 0:00:00
# Downloading buildingregulariser-0.2.5-py3-none-any.whl (20 kB)
# Downloading leafmap-0.63.1-py2.py3-none-any.whl (669 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 669.2/669.2 kB 38.8 MB/s eta 0:00:00
# Downloading localtileserver-1.0.0-py3-none-any.whl (33.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 49.5 MB/s eta 0:00:00
# Downloading patool-4.0.5-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.4/101.4 kB 8.7 MB/s eta 0:00:00
# Downloading segment_anything-1.0-py3-none-any.whl (36 kB)
# Downloading segment_geospatial-1.4.1-py2.py3-none-any.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 kB 12.6 MB/s eta 0:00:00
# Downloading smoothify-0.3.3-py3-none-any.whl (28 kB)
# Downloading duckdb-1.5.5-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (21.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 65.0 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.8 MB/s eta 0:00:00
# Downloading ipyvue-1.12.0-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 39.7 MB/s eta 0:00:00
# Downloading jupyter_loopback-0.3.3-py3-none-any.whl (37 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.1 MB/s eta 0:00:00
# Downloading geojson-3.3.0-py3-none-any.whl (15 kB)
# Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 71.0 MB/s eta 0:00:00
# Downloading maplibre-0.3.6-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 51.3 MB/s eta 0:00:00
# Downloading pystac_client-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.0 MB/s eta 0:00:00
# Downloading rio_cogeo-7.0.2-py3-none-any.whl (21 kB)
# Downloading rio_tiler-9.4.2-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 14.4 MB/s eta 0:00:00
# Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 6.7 MB/s eta 0:00:00
# Downloading morecantile-7.0.3-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.5 MB/s eta 0:00:00
# Downloading pystac-1.15.2-py3-none-any.whl (5.7 kB)
# Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 kB 12.3 MB/s eta 0:00:00
# Downloading eval_type_backport-0.4.0-py3-none-any.whl (6.4 kB)
# Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.4 MB/s eta 0:00:00
# Downloading portalocker-4.1.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 4.5 MB/s eta 0:00:00
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 4.7 MB/s eta 0:00:00
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 75.4 MB/s eta 0:00:00
# Downloading pystac_core-1.15.2-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.3/117.3 kB 7.8 MB/s eta 0:00:00
# Downloading pystac_ext_classification-2.0.1-py3-none-any.whl (7.4 kB)
# Downloading pystac_ext_datacube-2.2.1-py3-none-any.whl (7.1 kB)
# Downloading pystac_ext_eo-1.1.1-py3-none-any.whl (7.7 kB)
# Downloading pystac_ext_file-2.1.1-py3-none-any.whl (5.8 kB)
# Downloading pystac_ext_grid-1.1.1-py3-none-any.whl (3.6 kB)
# Downloading pystac_ext_item_assets-1.0.1-py3-none-any.whl (3.7 kB)
# Downloading pystac_ext_label-1.0.2-py3-none-any.whl (8.2 kB)
# Downloading pystac_ext_mgrs-1.0.1-py3-none-any.whl (4.1 kB)
# Downloading pystac_ext_mlm-1.4.1-py3-none-any.whl (13 kB)
# Downloading pystac_ext_pointcloud-1.0.1-py3-none-any.whl (6.5 kB)
# Downloading pystac_ext_projection-2.0.1-py3-none-any.whl (7.4 kB)
# Downloading pystac_ext_raster-1.1.1-py3-none-any.whl (6.8 kB)
# Downloading pystac_ext_render-2.0.0-py3-none-any.whl (5.0 kB)
# Downloading pystac_ext_sar-1.0.1-py3-none-any.whl (6.5 kB)
# Downloading pystac_ext_sat-1.0.1-py3-none-any.whl (4.9 kB)
# Downloading pystac_ext_scientific-1.0.1-py3-none-any.whl (5.5 kB)
# Downloading pystac_ext_storage-2.0.1-py3-none-any.whl (7.6 kB)
# Downloading pystac_ext_table-1.2.1-py3-none-any.whl (4.7 kB)
# Downloading pystac_ext_timestamps-1.1.1-py3-none-any.whl (4.6 kB)
# Downloading pystac_ext_version-1.2.1-py3-none-any.whl (5.8 kB)
# Downloading pystac_ext_view-1.0.1-py3-none-any.whl (4.8 kB)
# Downloading pystac_ext_xarray_assets-1.0.1-py3-none-any.whl (3.9 kB)
# Building wheels for collected packages: iopath
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=a192a185911db717b1e03190ae6ff04ff24055d51c4a73e3fdc1f6374b6ed5fd
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built iopath
# Installing collected packages: segment_anything, whitebox, typing_extensions, triton, portalocker, patool, jedi, geojson, ftfy, eval-type-backport, duckdb, color-operations, server-thread, pystac-core, iopath, pystac-ext-xarray-assets, pystac-ext-view, pystac-ext-version, pystac-ext-timestamps, pystac-ext-table, pystac-ext-storage, pystac-ext-scientific, pystac-ext-sat, pystac-ext-sar, pystac-ext-render, pystac-ext-raster, pystac-ext-projection, pystac-ext-pointcloud, pystac-ext-mgrs, pystac-ext-label, pystac-ext-item-assets, pystac-ext-grid, pystac-ext-file, pystac-ext-datacube, smoothify, pystac-ext-eo, pystac-ext-classification, morecantile, maplibre, buildingregulariser, segment-geospatial, rio-cogeo, pystac-ext-mlm, sam3, pystac, rio-tiler, pystac-client, jupyter-loopback, ipyvue, ipytree, whiteboxgui, ipyvuetify, localtileserver, leafmap
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.16.0
#     Uninstalling typing_extensions-4.16.0:
#       Successfully uninstalled typing_extensions-4.16.0
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
# Successfully installed buildingregulariser-0.2.5 color-operations-0.2.0 duckdb-1.5.5 eval-type-backport-0.4.0 ftfy-6.3.1 geojson-3.3.0 iopath-0.1.10 ipytree-0.2.2 ipyvue-1.12.0 ipyvuetify-1.11.3 jedi-0.20.0 jupyter-loopback-0.3.3 leafmap-0.63.1 localtileserver-1.0.0 maplibre-0.3.6 morecantile-7.0.3 patool-4.0.5 portalocker-4.1.0 pystac-1.15.2 pystac-client-0.9.0 pystac-core-1.15.2 pystac-ext-classification-2.0.1 pystac-ext-datacube-2.2.1 pystac-ext-eo-1.1.1 pystac-ext-file-2.1.1 pystac-ext-grid-1.1.1 pystac-ext-item-assets-1.0.1 pystac-ext-label-1.0.2 pystac-ext-mgrs-1.0.1 pystac-ext-mlm-1.4.1 pystac-ext-pointcloud-1.0.1 pystac-ext-projection-2.0.1 pystac-ext-raster-1.1.1 pystac-ext-render-2.0.0 pystac-ext-sar-1.0.1 pystac-ext-sat-1.0.1 pystac-ext-scientific-1.0.1 pystac-ext-storage-2.0.1 pystac-ext-table-1.2.1 pystac-ext-timestamps-1.1.1 pystac-ext-version-1.2.1 pystac-ext-view-1.0.1 pystac-ext-xarray-assets-1.0.1 rio-cogeo-7.0.2 rio-tiler-9.4.2 sam3-0.1.4 segment-geospatial-1.4.1 segment_anything-1.0 server-thread-0.3.0 smoothify-0.3.3 triton-3.7.1 typing_extensions-4.15.0 whitebox-2.3.6 whiteboxgui-2.3.0

# %% [markdown]
# ## Import Libraries

# %%
import leafmap

from samgeo import SamGeo3, download_file

# %% [markdown]
# ## Download Sample Data
#
# Let's download a sample satellite image covering the University of California, Berkeley, for testing:

# %%
url = "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/uc_berkeley.tif"
image_path = download_file(url)
# Out:
# Downloading...
# From: https://huggingface.co/datasets/giswqs/geospatial/resolve/main/uc_berkeley.tif
# To: /content/uc_berkeley.tif
# 100%|██████████| 12.7M/12.7M [00:00<00:00, 46.5MB/s]

# %%
m = leafmap.Map()
m.add_raster(image_path, layer_name="Satellite image")
m
# Out:
# Map(center=[37.87135, -122.25784999999999], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_i…

# %% [markdown]
# ## Request access to SAM3
#
# To use SAM3, you need to request access by filling out this form on Hugging Face: https://huggingface.co/facebook/sam3
#
# Once you have access, uncomment the following code block and run it.

# %%
from huggingface_hub import login
login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>AV9L-CFCS</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>RlTONORl</b> (token: <code>oauth-RlTONORl</code>).<br>This token will be refreshed automatically when it expires.</center>

# %% [markdown]
# ## Initialize SAM3
#
# When initializing SAM3, you can choose the backend from "meta", or "transformers".

# %%
sam3 = SamGeo3(backend="transformers", device=None, checkpoint_path=None, load_from_HF=True)
# Out:
# Using cpu device and transformers backend
# config.json:   0%|          | 0.00/25.8k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.44GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/1468 [00:00<?, ?it/s]
# processor_config.json:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/799 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.64M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/588 [00:00<?, ?B/s]

# %% [markdown]
# ## Set the image
#
# You can set the image by either passing the image path or the image URL.

# %%
sam3.set_image('EngKKU_map.png')

# %% [markdown]
# ## Generate masks with text prompt

# %%
sam3.generate_masks(prompt="building")
# Out:
# Found 65 objects.

# %% [markdown]
# ## Show the results

# %%
sam3.show_anns()
# Out:
# <PIL.Image.Image image mode=RGB size=1200x815>

# %% [markdown]
# ![annotation](https://github.com/user-attachments/assets/64323223-35a2-4e03-9cee-1b60fa0c12af)

# %%
sam3.show_masks()

# %% [markdown]
# ## Generate masks by bounding boxes

# %%
# Define boxes in [xmin, ymin, xmax, ymax] format
boxes = [[-122.2597, 37.8709, -122.2587, 37.8717]]

# Optional: specify which boxes are positive/negative prompts
box_labels = [True]  # True=include, False=exclude

# Generate masks
sam3.generate_masks_by_boxes(boxes, box_labels, box_crs="EPSG:4326")

# %%
sam3.show_boxes(boxes, box_labels, box_crs="EPSG:4326")

# %% [markdown]
# ![bbox](https://github.com/user-attachments/assets/87f0b9ab-a621-4e08-a4de-c90cbf0bf32f)

# %% [markdown]
# ## Show the results

# %%
sam3.show_anns()

# %% [markdown]
# ## Save Masks
#
# Save the generated masks to a file. If the input is a GeoTIFF, the output will be a GeoTIFF with the same georeferencing. Otherwise, it will be saved as PNG.

# %%
# Save masks with unique values for each object
# Since the input image is a GeoTIFF, the output will also be a GeoTIFF
sam3.save_masks(output="building_masks.tif", unique=True)

# %%
# Save as binary mask (all foreground pixels are 255)
sam3.save_masks(output="building_masks_binary.tif", unique=False)

# %% [markdown]
# ## Save Masks with Confidence Scores
#
# You can also save the confidence scores for each mask. The scores indicate the model's confidence for each predicted mask.

# %%
# Save masks and confidence scores
# Each pixel in the scores image will have the confidence value of its mask
sam3.save_masks(
    output="building_masks_with_scores.tif",
    save_scores="building_scores.tif",
    unique=True,
)

# %%
sam3.show_masks(cmap="coolwarm")

# %% [markdown]
# ![scores](https://github.com/user-attachments/assets/23ec9b07-0de9-4f72-81b2-83a3c499e94e)

# %% [markdown]
# ### Visualize Confidence Scores
#
# Let's visualize the confidence scores to see which masks have higher confidence:

# %%
m.add_raster("building_masks.tif", layer_name="Building masks", visible=False)
m.add_raster(
    "building_scores.tif",
    layer_name="Building scores",
    cmap="coolwarm",
    opacity=0.8,
    nodata=0,
)
m

# %% [markdown]
# ![map](https://github.com/user-attachments/assets/fa21320d-b4f3-48f9-a3f2-828f4ed1c567)
